# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split

# %%
ds=pd.read_csv("Pizza.csv")
ds
# Out:
#     brand     id   mois   prot    fat   ash  sodium   carb   cal
# 0       A  14069  27.82  21.43  44.87  5.11    1.77   0.77  4.93
# 1       A  14053  28.49  21.26  43.89  5.34    1.79   1.02  4.84
# 2       A  14025  28.35  19.99  45.78  5.08    1.63   0.80  4.95
# 3       A  14016  30.55  20.15  43.13  4.79    1.61   1.38  4.74
# 4       A  14005  30.49  21.28  41.65  4.82    1.64   1.76  4.67
# ..    ...    ...    ...    ...    ...   ...     ...    ...   ...
# 295     J  34044  44.91  11.07  17.00  2.49    0.66  25.36  2.91
# 296     J  24069  43.15  11.79  18.46  2.43    0.67  24.17  3.10
# 297     J  34039  44.55  11.01  16.03  2.43    0.64  25.98  2.92
# 298     J  14044  47.60  10.43  15.18  2.32    0.56  24.47  2.76
# 299     J  14045  46.84   9.91  15.50  2.27    0.57  25.48  2.81
#
# [300 rows x 9 columns]

# %%
topic=[]
for i in ds:
    topic.append(i)
a=topic.pop(0)
topic.append(a)
mdt=pd.DataFrame(ds[topic])
mdt
# Out:
#         id   mois   prot    fat   ash  sodium   carb   cal brand
# 0    14069  27.82  21.43  44.87  5.11    1.77   0.77  4.93     A
# 1    14053  28.49  21.26  43.89  5.34    1.79   1.02  4.84     A
# 2    14025  28.35  19.99  45.78  5.08    1.63   0.80  4.95     A
# 3    14016  30.55  20.15  43.13  4.79    1.61   1.38  4.74     A
# 4    14005  30.49  21.28  41.65  4.82    1.64   1.76  4.67     A
# ..     ...    ...    ...    ...   ...     ...    ...   ...   ...
# 295  34044  44.91  11.07  17.00  2.49    0.66  25.36  2.91     J
# 296  24069  43.15  11.79  18.46  2.43    0.67  24.17  3.10     J
# 297  34039  44.55  11.01  16.03  2.43    0.64  25.98  2.92     J
# 298  14044  47.60  10.43  15.18  2.32    0.56  24.47  2.76     J
# 299  14045  46.84   9.91  15.50  2.27    0.57  25.48  2.81     J
#
# [300 rows x 9 columns]

# %%
mdt=OrdinalEncoder().fit_transform(ds[topic])
mdt=pd.DataFrame(mdt)
mdt.columns=topic
mdt
feature=topic[:-1]

# %%
X_train,X_test,y_train,y_test=train_test_split(mdt[feature],mdt[topic[-1]])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
 
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.decomposition import PCA
 
pca = PCA(n_components = 3)
 
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)
# Out:
# array([[ 1.79707432, -0.5925002 , -0.09352421],
#        [-1.7001087 ,  0.78214229, -1.58190407],
#        [-2.52964969,  0.09785944,  1.43478214],
#        [ 3.39007792,  2.97484789,  0.5167272 ],
#        [-1.96344139,  2.10272392, -1.58259302],
#        [-2.11674684,  0.2186191 , -1.52819275],
#        [-2.2094624 ,  0.07025529, -0.63614846],
#        [ 2.21595331,  0.02843572, -0.05182073],
#        [ 3.50100244,  2.99199907,  0.37454044],
#        [ 1.59826722, -1.76185885,  1.68850109],
#        [ 1.68842959, -0.24975009, -1.34364973],
#        [-1.89233727,  1.26287904, -0.11767254],
#        [-2.57926851,  1.32943644,  0.10903006],
#        [ 2.4485662 , -0.02015097,  0.87234401],
#        [-2.17297128,  2.15492576, -0.27843839],
#        [-2.34319578, -1.17208004,  1.5138937 ],
#        [ 1.68875731, -0.56582862,  1.31561906],
#        [ 3.16558263,  2.49847001, -1.47349169],
#        [ 1.88905419, -0.56551167, -1.33134864],
#        [-1.8540112 , -0.12096232,  1.45855945],
# ...

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split

ds=pd.read_csv("Pizza.csv")
print(f"Initial Dataset : \n\n{ds.head()}")

topic=[]
for i in ds:
    topic.append(i)
a=topic.pop(0)
topic.append(a)
mdt=pd.DataFrame(ds[topic])
#print(f"\n{mdt.head()}")

mdt=OrdinalEncoder().fit_transform(ds[topic])
mdt=pd.DataFrame(mdt)
mdt.columns=topic
print(f"\n\nModified Dataset : \n\n{mdt}")
feature=topic[:-1]

X_train,X_test,y_train,y_test=train_test_split(mdt[feature],mdt['brand'],random_state=142,test_size=0.3)

from sklearn.decomposition import PCA
 
pca = PCA(n_components = int(input("Enter no.of.features : ")))
print()
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)
final=pd.DataFrame(X_test)
final.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-feb0a5f6a40e> in <module>()
#       3 from sklearn.model_selection import train_test_split
#       4
# ----> 5 ds=pd.read_csv("Pizza.csv")
#       6 print(f"Initial Dataset : \n\n{ds.head()}")
#       7
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
